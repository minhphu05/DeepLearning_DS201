# %% [markdown]
# # BÀI THỰC HÀNH 5: KIẾN TRÚC TRANSFORMER ENCODER

# %% [markdown]
# <b>Hướng dẫn nộp bài:</b> Các bạn commit và push code lên github, sử dụng file txt đặt tên theo cú pháp <MSSV>.txt chứa đường link dẫn đến github của bài thực hành và nộp file txt này tên courses.

# %% [markdown]
# ### Bài 1: Xây dựng mô hình Transformer Encoder gồm 3 lớp theo mô tả trong nghiên cứu [Attention is all you need](https://proceedings.neurips.cc/paper_files/paper/2017/file/3f5ee243547dee91fbd053c1c4a845aa-Paper.pdf). Huấn luyện mô hình này cho bài toán phân loại domain câu bình luận trên bộ dữ liệu [UIT-ViOCD](https://drive.google.com/drive/folders/1Lu9axyLkw7dMx80uLRgvCnZsmNzhJWAa?usp=sharing).

# %% [markdown]
# ### Bài 2: Xây dựng mô hình Transformer Encoder gồm 3 lớp theo mô tả trong nghiên cứu [Attention is all you need](https://proceedings.neurips.cc/paper_files/paper/2017/file/3f5ee243547dee91fbd053c1c4a845aa-Paper.pdf). Huấn luyện mô hình này cho bài toán gán nhãn chuỗi trên bộ dữ liệu [PhoNERT](https://github.com/VinAIResearch/PhoNER_COVID19).

# %% [markdown]
# # 23521758 Source code

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !git clone https://github.com/tyngoc1912/DS201.Q11
# Out:
# Cloning into 'DS201.Q11'...
# remote: Enumerating objects: 135, done.
# remote: Counting objects: 100% (135/135), done.
# remote: Compressing objects: 100% (105/105), done.
# remote: Total 135 (delta 38), reused 83 (delta 20), pack-reused 0 (from 0)
# Receiving objects: 100% (135/135), 47.37 MiB | 15.22 MiB/s, done.
# Resolving deltas: 100% (38/38), done.

# %%
# !pip install pyvi
# Out:
# Collecting pyvi
#   Downloading pyvi-0.1.1-py2.py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from pyvi) (1.6.1)
# Collecting sklearn-crfsuite (from pyvi)
#   Downloading sklearn_crfsuite-0.5.0-py2.py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->pyvi) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->pyvi) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->pyvi) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->pyvi) (3.6.0)
# Collecting python-crfsuite>=0.9.7 (from sklearn-crfsuite->pyvi)
#   Downloading python_crfsuite-0.9.12-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (4.3 kB)
# Requirement already satisfied: tabulate>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from sklearn-crfsuite->pyvi) (0.9.0)
# Requirement already satisfied: tqdm>=2.0 in /usr/local/lib/python3.12/dist-packages (from sklearn-crfsuite->pyvi) (4.67.1)
# Downloading pyvi-0.1.1-py2.py3-none-any.whl (8.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 19.2 MB/s eta 0:00:0000:0100:01
# Downloading sklearn_crfsuite-0.5.0-py2.py3-none-any.whl (10 kB)
# Downloading python_crfsuite-0.9.12-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 51.6 MB/s eta 0:00:00
# Installing collected packages: python-crfsuite, sklearn-crfsuite, pyvi
# Successfully installed python-crfsuite-0.9.12 pyvi-0.1.1 sklearn-crfsuite-0.5.0

# %% [markdown]
# ## Bai 1

# %%
# %cd DS201.Q11/Lab05
# Out:
# /kaggle/working/DS201.Q11/Lab05

# %%
# %cd Bai1
# Out:
# /kaggle/working/DS201.Q11/Lab05/Bai1

# %%
# !python main.py
# Out:
# 13:52:18 - INFO - Using device: cuda
# 13:52:18 - INFO - Model Config: d_model=256, layers=2, heads=4
# 13:52:18 - INFO - Building Vocabulary...
# 13:52:21 - INFO - Vocab Size: 3140 tokens
# 13:52:21 - INFO - Labels (4): {'app': 0, 'cosmetic': 1, 'fashion': 2, 'mobile': 3}
# 13:52:23 - INFO - Loaded 4350 samples from /kaggle/working/DS201.Q11/Lab05/ViOCD/train.json. Skipped 37 short/empty samples.
# 13:52:23 - INFO - Loaded 545 samples from /kaggle/working/DS201.Q11/Lab05/ViOCD/dev.json. Skipped 3 short/empty samples.
# 13:52:23 - INFO - Initializing Transformer Model (Base)...
# 13:52:26 - INFO - Start Training...
# 13:52:32 - INFO - Epoch 1/30 | Train Loss: 1.4979 | Val Loss: 1.1394 | Acc: 0.3376 | F1: 0.2718 [BEST MODEL SAVED]
# 13:52:37 - INFO - Epoch 2/30 | Train Loss: 1.2037 | Val Loss: 1.1172 | Acc: 0.3817 | F1: 0.2853 [BEST MODEL SAVED]
# 13:52:42 - INFO - Epoch 3/30 | Train Loss: 1.1544 | Val Loss: 0.9458 | Acc: 0.3596 | F1: 0.3250 [BEST MODEL SAVED]
# 13:52:47 - INFO - Epoch 4/30 | Train Loss: 1.0631 | Val Loss: 1.0075 | Acc: 0.2587 | F1: 0.2544
# 13:52:52 - INFO - Epoch 5/30 | Train Loss: 0.9610 | Val Loss: 0.7597 | Acc: 0.4789 | F1: 0.3946 [BEST MODEL SAVED]
# 13:52:57 - INFO - Epoch 6/30 | Train Loss: 0.8833 | Val Loss: 0.7349 | Acc: 0.4734 | F1: 0.4035 [BEST MODEL SAVED]
# 13:53:02 - INFO - Epoch 7/30 | Train Loss: 0.8521 | Val Loss: 0.7107 | Acc: 0.5101 | F1: 0.4058 [BEST MODEL SAVED]
# 13:53:07 - INFO - Epoch 8/30 | Train Loss: 0.8044 | Val Loss: 0.7426 | Acc: 0.5046 | F1: 0.4083 [BEST MODEL SAVED]
# 13:53:12 - INFO - Epoch 9/30 | Train Loss: 0.7895 | Val Loss: 0.7953 | Acc: 0.5138 | F1: 0.4057
# 13:53:18 - INFO - Epoch 10/30 | Train Loss: 0.7202 | Val Loss: 0.8018 | Acc: 0.5046 | F1: 0.3985
# 13:53:23 - INFO - Epoch 11/30 | Train Loss: 0.7090 | Val Loss: 0.9468 | Acc: 0.5138 | F1: 0.4115 [BEST MODEL SAVED]
# 13:53:28 - INFO - Epoch 12/30 | Train Loss: 0.7058 | Val Loss: 0.7913 | Acc: 0.5064 | F1: 0.4263 [BEST MODEL SAVED]
# 13:53:33 - INFO - Epoch 13/30 | Train Loss: 0.6599 | Val Loss: 0.7908 | Acc: 0.5119 | F1: 0.4134
# 13:53:38 - INFO - Epoch 14/30 | Train Loss: 0.6671 | Val Loss: 0.7824 | Acc: 0.5028 | F1: 0.4173
# 13:53:43 - INFO - Epoch 15/30 | Train Loss: 0.6434 | Val Loss: 0.8255 | Acc: 0.5156 | F1: 0.4083
# 13:53:48 - INFO - Epoch 16/30 | Train Loss: 0.6574 | Val Loss: 0.9014 | Acc: 0.5174 | F1: 0.4072
# 13:53:53 - INFO - Epoch 17/30 | Train Loss: 0.6287 | Val Loss: 0.8811 | Acc: 0.4972 | F1: 0.4206
# 13:53:58 - INFO - Epoch 18/30 | Train Loss: 0.6418 | Val Loss: 0.8322 | Acc: 0.5156 | F1: 0.4165
# 13:54:03 - INFO - Epoch 19/30 | Train Loss: 0.6098 | Val Loss: 0.8097 | Acc: 0.5009 | F1: 0.4209
# 13:54:08 - INFO - Epoch 20/30 | Train Loss: 0.6030 | Val Loss: 0.8053 | Acc: 0.5046 | F1: 0.4174
# 13:54:13 - INFO - Epoch 21/30 | Train Loss: 0.6006 | Val Loss: 0.8558 | Acc: 0.5009 | F1: 0.4082
# 13:54:18 - INFO - Epoch 22/30 | Train Loss: 0.5935 | Val Loss: 0.8798 | Acc: 0.5046 | F1: 0.4082
# 13:54:23 - INFO - Epoch 23/30 | Train Loss: 0.5989 | Val Loss: 0.9420 | Acc: 0.5046 | F1: 0.4016
# 13:54:28 - INFO - Epoch 24/30 | Train Loss: 0.6007 | Val Loss: 0.8473 | Acc: 0.5284 | F1: 0.4246
# 13:54:33 - INFO - Epoch 25/30 | Train Loss: 0.6012 | Val Loss: 0.9547 | Acc: 0.5028 | F1: 0.4116
# 13:54:38 - INFO - Epoch 26/30 | Train Loss: 0.5704 | Val Loss: 0.9450 | Acc: 0.4899 | F1: 0.4099
# 13:54:43 - INFO - Epoch 27/30 | Train Loss: 0.5737 | Val Loss: 0.8801 | Acc: 0.5064 | F1: 0.3980
# 13:54:49 - INFO - Epoch 28/30 | Train Loss: 0.5868 | Val Loss: 0.9595 | Acc: 0.4991 | F1: 0.3970
# 13:54:54 - INFO - Epoch 29/30 | Train Loss: 0.5939 | Val Loss: 1.0519 | Acc: 0.5083 | F1: 0.3946
# 13:54:59 - INFO - Epoch 30/30 | Train Loss: 0.5864 | Val Loss: 0.8492 | Acc: 0.5083 | F1: 0.4144
# 13:54:59 - INFO - Training Completed.
# 13:54:59 - INFO - Evaluating on Test Set...
# 13:54:59 - INFO - Loaded best model from /kaggle/working/transformer_base.pth
# 13:54:59 - INFO - Loaded 547 samples from /kaggle/working/DS201.Q11/Lab05/ViOCD/test.json. Skipped 2 short/empty samples.
# 13:54:59 - INFO - TEST RESULTS | Loss: 0.7744 | Accuracy: 0.5283 | F1: 0.4590
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#          app       0.00      0.00      0.00       193
#     cosmetic       0.81      0.70      0.75       150
#      fashion       0.69      0.90      0.78       158
#       mobile       0.20      0.91      0.33        46
#
#     accuracy                           0.53       547
#    macro avg       0.42      0.63      0.46       547
# weighted avg       0.44      0.53      0.46       547

# %% [markdown]
# ## Bai 2

# %%
# %cd DS201.Q11/Lab05
# Out:
# /kaggle/working/DS201.Q11/Lab05

# %%
# %cd Bai2
# Out:
# /kaggle/working/DS201.Q11/Lab05/Bai2

# %%
# !python main.py
# Out:
# 13:56:12 - INFO - Using device: cuda
# 13:56:12 - INFO - Building Vocabulary...
# Building vocab from: /kaggle/working/DS201.Q11/Lab05/PhoNER_COVID19/train_word.json
# File /kaggle/working/DS201.Q11/Lab05/PhoNER_COVID19/train_word.json có vẻ là JSON Lines. Đang chuyển sang chế độ đọc từng dòng...
# Vocab size: 4741
# Num tags: 20
# 13:56:12 - INFO - Vocab Size: 4741
# 13:56:12 - INFO - Tags (20): {'B-AGE': 0, 'B-DATE': 1, 'B-GENDER': 2, 'B-JOB': 3, 'B-LOCATION': 4, 'B-NAME': 5, 'B-ORGANIZATION': 6, 'B-PATIENT_ID': 7, 'B-SYMPTOM_AND_DISEASE': 8, 'B-TRANSPORTATION': 9, 'I-AGE': 10, 'I-DATE': 11, 'I-JOB': 12, 'I-LOCATION': 13, 'I-NAME': 14, 'I-ORGANIZATION': 15, 'I-PATIENT_ID': 16, 'I-SYMPTOM_AND_DISEASE': 17, 'I-TRANSPORTATION': 18, 'O': 19, '<pad_tag>': -100}
# Loading data from: /kaggle/working/DS201.Q11/Lab05/PhoNER_COVID19/train_word.json
# File /kaggle/working/DS201.Q11/Lab05/PhoNER_COVID19/train_word.json có vẻ là JSON Lines. Đang chuyển sang chế độ đọc từng dòng...
# Loading data from: /kaggle/working/DS201.Q11/Lab05/PhoNER_COVID19/dev_word.json
# File /kaggle/working/DS201.Q11/Lab05/PhoNER_COVID19/dev_word.json có vẻ là JSON Lines. Đang chuyển sang chế độ đọc từng dòng...
# 13:56:12 - INFO - Initializing Transformer Model for NER...
# 13:56:14 - INFO - Start Training...
# 13:56:16 - INFO - Epoch 1/15 | Train Loss: 1.0274 | Val Loss: 0.5758 | Acc: 0.8329 | F1: 0.8070 [BEST SAVED]
# 13:56:18 - INFO - Epoch 2/15 | Train Loss: 0.5339 | Val Loss: 0.3789 | Acc: 0.8834 | F1: 0.8771 [BEST SAVED]
# 13:56:20 - INFO - Epoch 3/15 | Train Loss: 0.3992 | Val Loss: 0.3035 | Acc: 0.9063 | F1: 0.9040 [BEST SAVED]
# 13:56:22 - INFO - Epoch 4/15 | Train Loss: 0.3271 | Val Loss: 0.2606 | Acc: 0.9208 | F1: 0.9195 [BEST SAVED]
# 13:56:24 - INFO - Epoch 5/15 | Train Loss: 0.2809 | Val Loss: 0.2411 | Acc: 0.9291 | F1: 0.9275 [BEST SAVED]
# 13:56:27 - INFO - Epoch 6/15 | Train Loss: 0.2471 | Val Loss: 0.2232 | Acc: 0.9360 | F1: 0.9353 [BEST SAVED]
# 13:56:29 - INFO - Epoch 7/15 | Train Loss: 0.2218 | Val Loss: 0.2186 | Acc: 0.9408 | F1: 0.9397 [BEST SAVED]
# 13:56:31 - INFO - Epoch 8/15 | Train Loss: 0.2071 | Val Loss: 0.2516 | Acc: 0.9371 | F1: 0.9339
# 13:56:33 - INFO - Epoch 9/15 | Train Loss: 0.1938 | Val Loss: 0.2292 | Acc: 0.9449 | F1: 0.9434 [BEST SAVED]
# 13:56:35 - INFO - Epoch 10/15 | Train Loss: 0.1771 | Val Loss: 0.2163 | Acc: 0.9465 | F1: 0.9460 [BEST SAVED]
# 13:56:37 - INFO - Epoch 11/15 | Train Loss: 0.1681 | Val Loss: 0.2217 | Acc: 0.9472 | F1: 0.9463 [BEST SAVED]
# 13:56:39 - INFO - Epoch 12/15 | Train Loss: 0.1615 | Val Loss: 0.2190 | Acc: 0.9495 | F1: 0.9483 [BEST SAVED]
# 13:56:41 - INFO - Epoch 13/15 | Train Loss: 0.1519 | Val Loss: 0.2344 | Acc: 0.9491 | F1: 0.9480
# 13:56:43 - INFO - Epoch 14/15 | Train Loss: 0.1464 | Val Loss: 0.2352 | Acc: 0.9516 | F1: 0.9505 [BEST SAVED]
# 13:56:45 - INFO - Epoch 15/15 | Train Loss: 0.1428 | Val Loss: 0.2362 | Acc: 0.9510 | F1: 0.9501
# 13:56:45 - INFO - Evaluating on Test Set...
# 13:56:45 - INFO - Loaded best model.
# Loading data from: /kaggle/working/DS201.Q11/Lab05/PhoNER_COVID19/test_word.json
# File /kaggle/working/DS201.Q11/Lab05/PhoNER_COVID19/test_word.json có vẻ là JSON Lines. Đang chuyển sang chế độ đọc từng dòng...
# 13:56:46 - INFO - TEST | Loss: 0.2735 | Acc: 0.9458 | F1: 0.9441
#
# Classification Report:
#
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#                        precision    recall  f1-score   support
#
#                 B-AGE       0.90      0.94      0.92       582
#                B-DATE       0.95      0.95      0.95      1654
#              B-GENDER       0.92      0.95      0.94       462
#                 B-JOB       0.72      0.54      0.61       173
#            B-LOCATION       0.89      0.85      0.87      4441
#                B-NAME       0.81      0.57      0.67       318
#        B-ORGANIZATION       0.84      0.80      0.82       771
#          B-PATIENT_ID       0.93      0.90      0.91      2005
# B-SYMPTOM_AND_DISEASE       0.89      0.81      0.85      1136
#      B-TRANSPORTATION       0.91      0.81      0.86       193
#                 I-AGE       0.00      0.00      0.00         6
#                I-DATE       0.91      0.98      0.95      1750
#                 I-JOB       0.54      0.18      0.27       114
#            I-LOCATION       0.88      0.80      0.84      4918
#                I-NAME       1.00      0.23      0.38        13
#        I-ORGANIZATION       0.80      0.84      0.82      2014
#          I-PATIENT_ID       0.00      0.00      0.00        27
# I-SYMPTOM_AND_DISEASE       0.87      0.72      0.78      1486
#      I-TRANSPORTATION       0.93      0.38      0.54        69
#                     O       0.97      0.98      0.97     63546
#
#              accuracy                           0.95     85678
#             macro avg       0.78      0.66      0.70     85678
#          weighted avg       0.94      0.95      0.94     85678
