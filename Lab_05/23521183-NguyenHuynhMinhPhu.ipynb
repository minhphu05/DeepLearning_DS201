# %% [markdown]
# # BÀI THỰC HÀNH 5: KIẾN TRÚC TRANSFORMER ENCODER

# %% [markdown]
# <b>Hướng dẫn nộp bài:</b> Các bạn commit và push code lên github, sử dụng file txt đặt tên theo cú pháp <MSSV>.txt chứa đường link dẫn đến github của bài thực hành và nộp file txt này tên courses.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/viocd-dataset/dev.json
# /kaggle/input/viocd-dataset/train.json
# /kaggle/input/viocd-dataset/test.json
# /kaggle/input/phoner-covid19/test_word.json
# /kaggle/input/phoner-covid19/dev_word.json
# /kaggle/input/phoner-covid19/train_word.json

# %%
# !git clone https://github.com/minhphu05/DeepLearning_DS201
# Out:
# Cloning into 'DeepLearning_DS201'...
# remote: Enumerating objects: 149, done.
# remote: Counting objects: 100% (92/92), done.
# remote: Compressing objects: 100% (68/68), done.
# remote: Total 149 (delta 23), reused 86 (delta 20), pack-reused 57 (from 2)
# Receiving objects: 100% (149/149), 147.34 MiB | 44.52 MiB/s, done.
# Resolving deltas: 100% (28/28), done.

# %%
# !pip install pyvi
# Out:
# Collecting pyvi
#   Downloading pyvi-0.1.1-py2.py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from pyvi) (1.2.2)
# Collecting sklearn-crfsuite (from pyvi)
#   Downloading sklearn_crfsuite-0.5.0-py2.py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->pyvi) (1.26.4)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->pyvi) (1.15.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->pyvi) (1.5.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->pyvi) (3.6.0)
# Collecting python-crfsuite>=0.9.7 (from sklearn-crfsuite->pyvi)
#   Downloading python_crfsuite-0.9.12-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (4.3 kB)
# Requirement already satisfied: tabulate>=0.4.2 in /usr/local/lib/python3.11/dist-packages (from sklearn-crfsuite->pyvi) (0.9.0)
# Requirement already satisfied: tqdm>=2.0 in /usr/local/lib/python3.11/dist-packages (from sklearn-crfsuite->pyvi) (4.67.1)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17.3->scikit-learn->pyvi) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17.3->scikit-learn->pyvi) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17.3->scikit-learn->pyvi) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17.3->scikit-learn->pyvi) (2025.3.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17.3->scikit-learn->pyvi) (2022.3.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17.3->scikit-learn->pyvi) (2.4.1)
# Requirement already satisfied: onemkl-license==2025.3.0 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17.3->scikit-learn->pyvi) (2025.3.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17.3->scikit-learn->pyvi) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17.3->scikit-learn->pyvi) (2022.3.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.17.3->scikit-learn->pyvi) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.17.3->scikit-learn->pyvi) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.17.3->scikit-learn->pyvi) (2024.2.0)
# Downloading pyvi-0.1.1-py2.py3-none-any.whl (8.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 47.7 MB/s eta 0:00:0000:0100:01
# Downloading sklearn_crfsuite-0.5.0-py2.py3-none-any.whl (10 kB)
# Downloading python_crfsuite-0.9.12-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 68.9 MB/s eta 0:00:00
# Installing collected packages: python-crfsuite, sklearn-crfsuite, pyvi
# Successfully installed python-crfsuite-0.9.12 pyvi-0.1.1 sklearn-crfsuite-0.5.0

# %% [markdown]
# ### Bài 1: Xây dựng mô hình Transformer Encoder gồm 3 lớp theo mô tả trong nghiên cứu [Attention is all you need](https://proceedings.neurips.cc/paper_files/paper/2017/file/3f5ee243547dee91fbd053c1c4a845aa-Paper.pdf). Huấn luyện mô hình này cho bài toán phân loại domain câu bình luận trên bộ dữ liệu [UIT-ViOCD](https://drive.google.com/drive/folders/1Lu9axyLkw7dMx80uLRgvCnZsmNzhJWAa?usp=sharing).

# %%
# !python /kaggle/working/DeepLearning_DS201/Lab_05/Bai01/main.py
# Out:
# 15:56:09 - INFO - Using device: cuda
# 15:56:09 - INFO - Model Config: d_model=256, layers=2, heads=4
# 15:56:09 - INFO - Building Vocabulary...
# 15:56:12 - INFO - Vocab Size: 3140 tokens
# 15:56:12 - INFO - Labels (4): {'app': 0, 'cosmetic': 1, 'fashion': 2, 'mobile': 3}
# 15:56:14 - INFO - Loaded 4350 samples from /kaggle/input/viocd-dataset/train.json. Skipped 37 short/empty samples.
# 15:56:15 - INFO - Loaded 545 samples from /kaggle/input/viocd-dataset/dev.json. Skipped 3 short/empty samples.
# 15:56:15 - INFO - Initializing Transformer Model (Base)...
# 15:56:17 - INFO - Start Training...
# 15:56:23 - INFO - Epoch 1/30 | Train Loss: 1.3316 | Val Loss: 1.1641 | Acc: 0.1523 | F1: 0.1236 [BEST MODEL SAVED]
# 15:56:28 - INFO - Epoch 2/30 | Train Loss: 1.2243 | Val Loss: 1.1035 | Acc: 0.3670 | F1: 0.2830 [BEST MODEL SAVED]
# 15:56:33 - INFO - Epoch 3/30 | Train Loss: 1.1604 | Val Loss: 0.9700 | Acc: 0.2899 | F1: 0.2549
# 15:56:38 - INFO - Epoch 4/30 | Train Loss: 1.0728 | Val Loss: 0.8360 | Acc: 0.4220 | F1: 0.3890 [BEST MODEL SAVED]
# 15:56:43 - INFO - Epoch 5/30 | Train Loss: 0.9511 | Val Loss: 0.8357 | Acc: 0.4881 | F1: 0.3900 [BEST MODEL SAVED]
# 15:56:48 - INFO - Epoch 6/30 | Train Loss: 0.8863 | Val Loss: 0.7212 | Acc: 0.5046 | F1: 0.4138 [BEST MODEL SAVED]
# 15:56:53 - INFO - Epoch 7/30 | Train Loss: 0.8555 | Val Loss: 0.7075 | Acc: 0.4807 | F1: 0.4129
# 15:56:58 - INFO - Epoch 8/30 | Train Loss: 0.7994 | Val Loss: 0.7119 | Acc: 0.4991 | F1: 0.4214 [BEST MODEL SAVED]
# 15:57:03 - INFO - Epoch 9/30 | Train Loss: 0.7745 | Val Loss: 0.7347 | Acc: 0.5229 | F1: 0.4469 [BEST MODEL SAVED]
# 15:57:08 - INFO - Epoch 10/30 | Train Loss: 0.7533 | Val Loss: 0.8245 | Acc: 0.5321 | F1: 0.4157
# 15:57:13 - INFO - Epoch 11/30 | Train Loss: 0.7284 | Val Loss: 0.7335 | Acc: 0.4991 | F1: 0.4185
# 15:57:18 - INFO - Epoch 12/30 | Train Loss: 0.7056 | Val Loss: 0.7940 | Acc: 0.5174 | F1: 0.4116
# 15:57:23 - INFO - Epoch 13/30 | Train Loss: 0.6944 | Val Loss: 0.7678 | Acc: 0.5119 | F1: 0.4250
# 15:57:28 - INFO - Epoch 14/30 | Train Loss: 0.6568 | Val Loss: 0.7810 | Acc: 0.5101 | F1: 0.4310
# 15:57:33 - INFO - Epoch 15/30 | Train Loss: 0.6430 | Val Loss: 0.8058 | Acc: 0.5119 | F1: 0.4200
# 15:57:38 - INFO - Epoch 16/30 | Train Loss: 0.6444 | Val Loss: 0.8424 | Acc: 0.5009 | F1: 0.4169
# 15:57:43 - INFO - Epoch 17/30 | Train Loss: 0.6479 | Val Loss: 0.7972 | Acc: 0.4954 | F1: 0.4256
# 15:57:48 - INFO - Epoch 18/30 | Train Loss: 0.6198 | Val Loss: 0.8551 | Acc: 0.5046 | F1: 0.4231
# 15:57:53 - INFO - Epoch 19/30 | Train Loss: 0.6096 | Val Loss: 0.7807 | Acc: 0.5119 | F1: 0.4116
# 15:57:59 - INFO - Epoch 20/30 | Train Loss: 0.6012 | Val Loss: 0.7907 | Acc: 0.5119 | F1: 0.4105
# 15:58:04 - INFO - Epoch 21/30 | Train Loss: 0.6058 | Val Loss: 0.9115 | Acc: 0.5009 | F1: 0.4170
# 15:58:09 - INFO - Epoch 22/30 | Train Loss: 0.5915 | Val Loss: 0.8606 | Acc: 0.5083 | F1: 0.4141
# 15:58:14 - INFO - Epoch 23/30 | Train Loss: 0.5769 | Val Loss: 0.8793 | Acc: 0.5009 | F1: 0.4228
# 15:58:19 - INFO - Epoch 24/30 | Train Loss: 0.5820 | Val Loss: 0.9417 | Acc: 0.5119 | F1: 0.4140
# 15:58:24 - INFO - Epoch 25/30 | Train Loss: 0.6177 | Val Loss: 0.8170 | Acc: 0.4789 | F1: 0.3988
# 15:58:29 - INFO - Epoch 26/30 | Train Loss: 0.5853 | Val Loss: 0.8581 | Acc: 0.5101 | F1: 0.4247
# 15:58:34 - INFO - Epoch 27/30 | Train Loss: 0.5950 | Val Loss: 0.8784 | Acc: 0.5009 | F1: 0.4132
# 15:58:39 - INFO - Epoch 28/30 | Train Loss: 0.5624 | Val Loss: 0.8509 | Acc: 0.4826 | F1: 0.3912
# 15:58:44 - INFO - Epoch 29/30 | Train Loss: 0.5778 | Val Loss: 0.8999 | Acc: 0.5083 | F1: 0.4094
# 15:58:49 - INFO - Epoch 30/30 | Train Loss: 0.5774 | Val Loss: 0.9498 | Acc: 0.4954 | F1: 0.4048
# 15:58:49 - INFO - Training Completed.
# 15:58:49 - INFO - Evaluating on Test Set...
# 15:58:49 - INFO - Loaded best model from /kaggle/working/transformer_base.pth
# 15:58:49 - INFO - Loaded 547 samples from /kaggle/input/viocd-dataset/test.json. Skipped 2 short/empty samples.
# 15:58:50 - INFO - TEST RESULTS | Loss: 0.7280 | Accuracy: 0.5448 | F1: 0.4764
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#          app       0.00      0.00      0.00       193
#     cosmetic       0.80      0.77      0.79       150
#      fashion       0.74      0.92      0.82       158
#       mobile       0.18      0.80      0.29        46
#
#     accuracy                           0.54       547
#    macro avg       0.43      0.62      0.47       547
# weighted avg       0.45      0.54      0.48       547

# %% [markdown]
# ### Bài 2: Xây dựng mô hình Transformer Encoder gồm 3 lớp theo mô tả trong nghiên cứu [Attention is all you need](https://proceedings.neurips.cc/paper_files/paper/2017/file/3f5ee243547dee91fbd053c1c4a845aa-Paper.pdf). Huấn luyện mô hình này cho bài toán gán nhãn chuỗi trên bộ dữ liệu [PhoNERT](https://github.com/VinAIResearch/PhoNER_COVID19).

# %%
# !python /kaggle/working/DeepLearning_DS201/Lab_05/Bai02/main.py
# Out:
# 15:59:04 - INFO - Using device: cuda
# 15:59:04 - INFO - Building Vocabulary...
# Building vocab from: /kaggle/input/phoner-covid19/train_word.json
# File /kaggle/input/phoner-covid19/train_word.json có vẻ là JSON Lines. Đang chuyển sang chế độ đọc từng dòng...
# Vocab size: 4741
# Num tags: 20
# 15:59:04 - INFO - Vocab Size: 4741
# 15:59:04 - INFO - Tags (20): {'B-AGE': 0, 'B-DATE': 1, 'B-GENDER': 2, 'B-JOB': 3, 'B-LOCATION': 4, 'B-NAME': 5, 'B-ORGANIZATION': 6, 'B-PATIENT_ID': 7, 'B-SYMPTOM_AND_DISEASE': 8, 'B-TRANSPORTATION': 9, 'I-AGE': 10, 'I-DATE': 11, 'I-JOB': 12, 'I-LOCATION': 13, 'I-NAME': 14, 'I-ORGANIZATION': 15, 'I-PATIENT_ID': 16, 'I-SYMPTOM_AND_DISEASE': 17, 'I-TRANSPORTATION': 18, 'O': 19, '<pad_tag>': -100}
# Loading data from: /kaggle/input/phoner-covid19/train_word.json
# File /kaggle/input/phoner-covid19/train_word.json có vẻ là JSON Lines. Đang chuyển sang chế độ đọc từng dòng...
# Loading data from: /kaggle/input/phoner-covid19/dev_word.json
# File /kaggle/input/phoner-covid19/dev_word.json có vẻ là JSON Lines. Đang chuyển sang chế độ đọc từng dòng...
# 15:59:04 - INFO - Initializing Transformer Model for NER...
# 15:59:05 - INFO - Start Training...
# 15:59:07 - INFO - Epoch 1/15 | Train Loss: 0.9568 | Val Loss: 0.5391 | Acc: 0.8404 | F1: 0.8349 [BEST SAVED]
# 15:59:10 - INFO - Epoch 2/15 | Train Loss: 0.5106 | Val Loss: 0.3607 | Acc: 0.8885 | F1: 0.8812 [BEST SAVED]
# 15:59:12 - INFO - Epoch 3/15 | Train Loss: 0.3851 | Val Loss: 0.3024 | Acc: 0.9067 | F1: 0.9063 [BEST SAVED]
# 15:59:14 - INFO - Epoch 4/15 | Train Loss: 0.3197 | Val Loss: 0.2460 | Acc: 0.9255 | F1: 0.9238 [BEST SAVED]
# 15:59:16 - INFO - Epoch 5/15 | Train Loss: 0.2739 | Val Loss: 0.2348 | Acc: 0.9296 | F1: 0.9297 [BEST SAVED]
# 15:59:18 - INFO - Epoch 6/15 | Train Loss: 0.2461 | Val Loss: 0.2150 | Acc: 0.9369 | F1: 0.9364 [BEST SAVED]
# 15:59:20 - INFO - Epoch 7/15 | Train Loss: 0.2214 | Val Loss: 0.2115 | Acc: 0.9420 | F1: 0.9408 [BEST SAVED]
# 15:59:22 - INFO - Epoch 8/15 | Train Loss: 0.2023 | Val Loss: 0.2039 | Acc: 0.9444 | F1: 0.9441 [BEST SAVED]
# 15:59:24 - INFO - Epoch 9/15 | Train Loss: 0.1892 | Val Loss: 0.2132 | Acc: 0.9464 | F1: 0.9457 [BEST SAVED]
# 15:59:27 - INFO - Epoch 10/15 | Train Loss: 0.1733 | Val Loss: 0.2087 | Acc: 0.9489 | F1: 0.9481 [BEST SAVED]
# 15:59:29 - INFO - Epoch 11/15 | Train Loss: 0.1649 | Val Loss: 0.2136 | Acc: 0.9484 | F1: 0.9472
# 15:59:31 - INFO - Epoch 12/15 | Train Loss: 0.1593 | Val Loss: 0.2177 | Acc: 0.9499 | F1: 0.9495 [BEST SAVED]
# 15:59:33 - INFO - Epoch 13/15 | Train Loss: 0.1487 | Val Loss: 0.2233 | Acc: 0.9518 | F1: 0.9513 [BEST SAVED]
# 15:59:35 - INFO - Epoch 14/15 | Train Loss: 0.1436 | Val Loss: 0.2283 | Acc: 0.9510 | F1: 0.9510
# 15:59:37 - INFO - Epoch 15/15 | Train Loss: 0.1377 | Val Loss: 0.2265 | Acc: 0.9537 | F1: 0.9533 [BEST SAVED]
# 15:59:37 - INFO - Evaluating on Test Set...
# 15:59:37 - INFO - Loaded best model.
# Loading data from: /kaggle/input/phoner-covid19/test_word.json
# File /kaggle/input/phoner-covid19/test_word.json có vẻ là JSON Lines. Đang chuyển sang chế độ đọc từng dòng...
# 15:59:38 - INFO - TEST | Loss: 0.2559 | Acc: 0.9492 | F1: 0.9481
#
# Classification Report:
#
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                        precision    recall  f1-score   support
#
#                 B-AGE       0.83      0.96      0.89       582
#                B-DATE       0.96      0.95      0.96      1654
#              B-GENDER       0.91      0.95      0.93       462
#                 B-JOB       0.71      0.61      0.65       173
#            B-LOCATION       0.90      0.87      0.88      4441
#                B-NAME       0.81      0.62      0.70       318
#        B-ORGANIZATION       0.84      0.84      0.84       771
#          B-PATIENT_ID       0.93      0.90      0.92      2005
# B-SYMPTOM_AND_DISEASE       0.88      0.80      0.84      1136
#      B-TRANSPORTATION       0.93      0.82      0.87       193
#                 I-AGE       0.00      0.00      0.00         6
#                I-DATE       0.93      0.99      0.96      1750
#                 I-JOB       0.61      0.17      0.26       114
#            I-LOCATION       0.85      0.86      0.86      4918
#                I-NAME       1.00      0.15      0.27        13
#        I-ORGANIZATION       0.86      0.82      0.84      2014
#          I-PATIENT_ID       0.00      0.00      0.00        27
# I-SYMPTOM_AND_DISEASE       0.79      0.74      0.76      1486
#      I-TRANSPORTATION       0.94      0.46      0.62        69
#                     O       0.97      0.98      0.98     63546
#
#              accuracy                           0.95     85678
#             macro avg       0.78      0.67      0.70     85678
#          weighted avg       0.95      0.95      0.95     85678
