# %% [markdown]
# # BÀI THỰC HÀNH 4: MẠNG NEURAL HỒI QUY

# %% [markdown]
# <b>Hướng dẫn nộp bài:</b> Các bạn commit và push code lên github, sử dụng file txt đặt tên theo cú pháp <MSSV>.txt chứa đường link dẫn đến github của bài thực hành và nộp file txt này tên courses.
#
# Bộ dữ liệu sử dụng: [PhoMT](https://drive.google.com/drive/folders/186OAOuSEYEDVcry7WP5UBdqECXo26QAb?usp=drive_link).

# %% [markdown]
# #### Bài 1: Xây dựng kiến trúc Encoder-Decoder gồm 3 lớp LSTM cho module encoder và 3 lớp LSTM cho module decoder, với hidden size là 256, cho bài toán dịch máy từ tiếng Anh sang tiếng Việt. Huấn luyện mô hình này trên bộ dữ liệu PhoMT sử dụng Adam làm phương thức tối ưu tham số. Đánh giá độ hiệu quả của mô hình sử dụng độ đo ROUGE-L.

# %% [markdown]
# #### Bài 2: Xây dựng kiến trúc Encoder-Decoder gồm 3 lớp LSTM cho module encoder và 3 lớp LSTM cho module decoder, với hidden size là 256, cho bài toán dịch máy từ tiếng Anh sang tiếng Việt. Module decoder được trang bị kỹ thuật attention theo mô tả của nghiên cứu "[Neural Machine Translation by Jointly Learning to Align and Translate](https://arxiv.org/abs/1409.0473)". Huấn luyện mô hình này trên bộ dữ liệu PhoMT sử dụng Adam làm phương thức tối ưu tham số. Đánh giá độ hiệu quả của mô hình sử dụn độ đo ROUGE-L.

# %% [markdown]
# #### Bài 3: Xây dựng kiến trúc Encoder-Decoder gồm 3 lớp LSTM cho module encoder và 3 lớp LSTM cho module decoder, với hidden size là 256, cho bài toán dịch máy từ tiếng Anh sang tiếng Việt. Module decoder được trang bị kỹ thuật attention theo mô tả của nghiên cứu "[Effective Approaches to Attention-based Neural Machine Translation](https://arxiv.org/abs/1508.04025)". Huấn luyện mô hình này trên bộ dữ liệu PhoMT sử dụng Adam làm phương thức tối ưu tham số. Đánh giá độ hiệu quả của mô hình sử dụn độ đo ROUGE-L.

# %% [markdown]
# # 23521758 Source code

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/phomt-dataset/dataset/dev.json
# /kaggle/input/phomt-dataset/dataset/train.json
# /kaggle/input/phomt-dataset/dataset/test.json

# %%
# !git clone https://github.com/tyngoc1912/DS201.Q11
# %cd DS201.Q11/Lab04

# %%
# !apt-get update
# Out:
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,201 kB]
# Get:4 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [83.6 kB]
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:8 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:9 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,510 kB]
# Get:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,571 kB]
# Hit:12 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:13 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Hit:14 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [6,281 kB]
# Get:16 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 Packages [38.5 kB]
# Get:17 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,286 kB]
# Get:18 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [6,081 kB]
# Get:19 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,842 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,598 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,901 kB]
# Fetched 37.8 MB in 4s (8,520 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)

# %%
# !apt-get install default-jre
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   default-jre-headless fonts-dejavu-core fonts-dejavu-extra
#   libatk-wrapper-java libatk-wrapper-java-jni libxtst6 libxxf86dga1
#   openjdk-11-jdk-headless openjdk-11-jre openjdk-11-jre-headless x11-utils
# Suggested packages:
#   openjdk-11-demo openjdk-11-source libnss-mdns fonts-ipafont-gothic
#   fonts-ipafont-mincho fonts-wqy-microhei | fonts-wqy-zenhei fonts-indic
#   mesa-utils
# The following NEW packages will be installed:
#   default-jre default-jre-headless fonts-dejavu-core fonts-dejavu-extra
#   libatk-wrapper-java libatk-wrapper-java-jni libxtst6 libxxf86dga1
#   openjdk-11-jre x11-utils
# The following packages will be upgraded:
#   openjdk-11-jdk-headless openjdk-11-jre-headless
# 2 upgraded, 10 newly installed, 0 to remove and 180 not upgraded.
# Need to get 120 MB of archives.
# After this operation, 12.5 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 openjdk-11-jdk-headless amd64 11.0.29+7-1ubuntu1~22.04 [73.6 MB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 openjdk-11-jre-headless amd64 11.0.29+7-1ubuntu1~22.04 [42.6 MB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 default-jre-headless amd64 2:1.11-72build2 [3,042 B]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxtst6 amd64 2:1.2.3-1build4 [13.4 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 openjdk-11-jre amd64 11.0.29+7-1ubuntu1~22.04 [214 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 default-jre amd64 2:1.11-72build2 [896 B]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-core all 2.37-2build1 [1,041 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-extra all 2.37-2build1 [2,041 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxxf86dga1 amd64 2:1.1.5-0ubuntu3 [12.6 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-utils amd64 7.7+5build2 [206 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-wrapper-java all 0.38.0-5build1 [53.1 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-wrapper-java-jni amd64 0.38.0-5build1 [49.0 kB]
# Fetched 120 MB in 8s (15.5 MB/s)
# (Reading database ... 128639 files and directories currently installed.)
# Preparing to unpack .../00-openjdk-11-jdk-headless_11.0.29+7-1ubuntu1~22.04_amd64.deb ...
# Unpacking openjdk-11-jdk-headless:amd64 (11.0.29+7-1ubuntu1~22.04) over (11.0.27+6~us1-0ubuntu1~22.04) ...
# Preparing to unpack .../01-openjdk-11-jre-headless_11.0.29+7-1ubuntu1~22.04_amd64.deb ...
# Unpacking openjdk-11-jre-headless:amd64 (11.0.29+7-1ubuntu1~22.04) over (11.0.27+6~us1-0ubuntu1~22.04) ...
# Selecting previously unselected package default-jre-headless.
# Preparing to unpack .../02-default-jre-headless_2%3a1.11-72build2_amd64.deb ...
# Unpacking default-jre-headless (2:1.11-72build2) ...
# Selecting previously unselected package libxtst6:amd64.
# Preparing to unpack .../03-libxtst6_2%3a1.2.3-1build4_amd64.deb ...
# Unpacking libxtst6:amd64 (2:1.2.3-1build4) ...
# Selecting previously unselected package openjdk-11-jre:amd64.
# Preparing to unpack .../04-openjdk-11-jre_11.0.29+7-1ubuntu1~22.04_amd64.deb ...
# Unpacking openjdk-11-jre:amd64 (11.0.29+7-1ubuntu1~22.04) ...
# Selecting previously unselected package default-jre.
# Preparing to unpack .../05-default-jre_2%3a1.11-72build2_amd64.deb ...
# Unpacking default-jre (2:1.11-72build2) ...
# Selecting previously unselected package fonts-dejavu-core.
# Preparing to unpack .../06-fonts-dejavu-core_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-core (2.37-2build1) ...
# Selecting previously unselected package fonts-dejavu-extra.
# Preparing to unpack .../07-fonts-dejavu-extra_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-extra (2.37-2build1) ...
# Selecting previously unselected package libxxf86dga1:amd64.
# Preparing to unpack .../08-libxxf86dga1_2%3a1.1.5-0ubuntu3_amd64.deb ...
# Unpacking libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Selecting previously unselected package x11-utils.
# Preparing to unpack .../09-x11-utils_7.7+5build2_amd64.deb ...
# Unpacking x11-utils (7.7+5build2) ...
# Selecting previously unselected package libatk-wrapper-java.
# Preparing to unpack .../10-libatk-wrapper-java_0.38.0-5build1_all.deb ...
# Unpacking libatk-wrapper-java (0.38.0-5build1) ...
# Selecting previously unselected package libatk-wrapper-java-jni:amd64.
# Preparing to unpack .../11-libatk-wrapper-java-jni_0.38.0-5build1_amd64.deb ...
# Unpacking libatk-wrapper-java-jni:amd64 (0.38.0-5build1) ...
# Setting up libxtst6:amd64 (2:1.2.3-1build4) ...
# Setting up openjdk-11-jre-headless:amd64 (11.0.29+7-1ubuntu1~22.04) ...
# Setting up libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Setting up openjdk-11-jre:amd64 (11.0.29+7-1ubuntu1~22.04) ...
# Setting up openjdk-11-jdk-headless:amd64 (11.0.29+7-1ubuntu1~22.04) ...
# Setting up fonts-dejavu-core (2.37-2build1) ...
# Setting up fonts-dejavu-extra (2.37-2build1) ...
# Setting up x11-utils (7.7+5build2) ...
# Setting up libatk-wrapper-java (0.38.0-5build1) ...
# Setting up default-jre-headless (2:1.11-72build2) ...
# Setting up default-jre (2:1.11-72build2) ...
# Setting up libatk-wrapper-java-jni:amd64 (0.38.0-5build1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for mailcap (3.70+nmu1ubuntu1) ...

# %%
# !pip install evaluate nltk
# Out:
# Collecting evaluate
#   Downloading evaluate-0.4.6-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (3.9.2)
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from evaluate) (4.4.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from evaluate) (1.26.4)
# Requirement already satisfied: dill in /usr/local/lib/python3.11/dist-packages (from evaluate) (0.4.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from evaluate) (2.2.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from evaluate) (2.32.5)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.11/dist-packages (from evaluate) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from evaluate) (3.6.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.11/dist-packages (from evaluate) (0.70.18)
# Requirement already satisfied: fsspec>=2021.05.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (2025.10.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from evaluate) (0.36.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from evaluate) (25.0)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk) (8.3.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk) (2025.11.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (3.20.0)
# Collecting pyarrow>=21.0.0 (from datasets>=2.0.0->evaluate)
#   Downloading pyarrow-22.0.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (3.2 kB)
# Requirement already satisfied: httpx<1.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (0.28.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (3.13.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.7.0->evaluate) (1.2.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->evaluate) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->evaluate) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->evaluate) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->evaluate) (2025.3.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->evaluate) (2022.3.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->evaluate) (2.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (2025.10.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.22.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<1.0.0->datasets>=2.0.0->evaluate) (4.11.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1.0.0->datasets>=2.0.0->evaluate) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1.0.0->datasets>=2.0.0->evaluate) (0.16.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.17.0)
# Requirement already satisfied: onemkl-license==2025.3.0 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17->evaluate) (2025.3.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17->evaluate) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17->evaluate) (2022.3.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.17->evaluate) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.17->evaluate) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.17->evaluate) (2024.2.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx<1.0.0->datasets>=2.0.0->evaluate) (1.3.1)
# Downloading evaluate-0.4.6-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 2.6 MB/s eta 0:00:00
# Downloading pyarrow-22.0.0-cp311-cp311-manylinux_2_28_x86_64.whl (47.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.7/47.7 MB 42.8 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: pyarrow, evaluate
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 19.0.1
#     Uninstalling pyarrow-19.0.1:
#       Successfully uninstalled pyarrow-19.0.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# pylibcudf-cu12 25.2.2 requires pyarrow<20.0.0a0,>=14.0.0; platform_machine == "x86_64", but you have pyarrow 22.0.0 which is incompatible.
# cudf-cu12 25.2.2 requires pyarrow<20.0.0a0,>=14.0.0; platform_machine == "x86_64", but you have pyarrow 22.0.0 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# cudf-polars-cu12 25.6.0 requires pylibcudf-cu12==25.6.*, but you have pylibcudf-cu12 25.2.2 which is incompatible.
# Successfully installed evaluate-0.4.6 pyarrow-22.0.0

# %%
# !python LSTM_bahdanau_main.py
# Out:
# 2025-12-07 11:37:00.686689: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765107420.896036    1177 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765107420.955334    1177 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# [nltk_data] Downloading package wordnet to /usr/share/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /usr/share/nltk_data...
# Loading vocab ...
# Creating model ...
# Loading METEOR metric...
# Downloading builder script: 7.02kB [00:00, 18.1MB/s]
# [nltk_data] Downloading package wordnet to /usr/share/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /usr/share/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /usr/share/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# Loading dataset ...
# Starting training ...
# Epoch 1 Training: 100%|██████████| 313/313 [02:41<00:00,  1.93it/s, loss=5.8631]
# Evaluating Epoch 1...
#    >>> [DEBUG] METEOR Calculated: 24.96%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [8399, 1574, 9, 3]}
# ratio: 0.9999999999999775
# --- Epoch 01 Complete (Time: 4m 16s) ---
# Training Loss: 6.0836 | Dev Loss: 6.1305
# ⭐️ Dev METEOR: 24.96%
# ⭐️ Dev BLEU-4: 0.33%
#  >>> SAVED: New best model found (BLEU-4: 0.33%)
#
#
# Epoch 2 Training: 100%|██████████| 313/313 [02:43<00:00,  1.91it/s, loss=5.6648]
# Evaluating Epoch 2...
#    >>> [DEBUG] METEOR Calculated: 23.00%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [8336, 1300, 15, 3]}
# ratio: 0.9999999999999775
# --- Epoch 02 Complete (Time: 4m 13s) ---
# Training Loss: 5.7571 | Dev Loss: 6.1135
# ⭐️ Dev METEOR: 23.00%
# ⭐️ Dev BLEU-4: 0.36%
#  >>> SAVED: New best model found (BLEU-4: 0.36%)
#
#
# Epoch 3 Training: 100%|██████████| 313/313 [02:41<00:00,  1.93it/s, loss=5.6072]
# Evaluating Epoch 3...
#    >>> [DEBUG] METEOR Calculated: 21.32%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [8570, 1263, 88, 24]}
# ratio: 0.9999999999999775
# --- Epoch 03 Complete (Time: 4m 11s) ---
# Training Loss: 5.6649 | Dev Loss: 6.0501
# ⭐️ Dev METEOR: 21.32%
# ⭐️ Dev BLEU-4: 0.94%
#  >>> SAVED: New best model found (BLEU-4: 0.94%)
#
#
# Epoch 4 Training: 100%|██████████| 313/313 [02:42<00:00,  1.92it/s, loss=5.2492]
# Evaluating Epoch 4...
#    >>> [DEBUG] METEOR Calculated: 31.81%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [11865, 2302, 151, 30]}
# ratio: 0.9999999999999775
# --- Epoch 04 Complete (Time: 4m 12s) ---
# Training Loss: 5.4751 | Dev Loss: 5.7174
# ⭐️ Dev METEOR: 31.81%
# ⭐️ Dev BLEU-4: 1.44%
#  >>> SAVED: New best model found (BLEU-4: 1.44%)
#
#
# Epoch 5 Training: 100%|██████████| 313/313 [02:41<00:00,  1.94it/s, loss=4.9443]
# Evaluating Epoch 5...
#    >>> [DEBUG] METEOR Calculated: 32.51%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [12681, 3030, 288, 59]}
# ratio: 0.9999999999999775
# --- Epoch 05 Complete (Time: 4m 11s) ---
# Training Loss: 5.0744 | Dev Loss: 5.5180
# ⭐️ Dev METEOR: 32.51%
# ⭐️ Dev BLEU-4: 2.18%
#  >>> SAVED: New best model found (BLEU-4: 2.18%)
#
#
# Epoch 6 Training: 100%|██████████| 313/313 [02:42<00:00,  1.92it/s, loss=4.8839]
# Evaluating Epoch 6...
#    >>> [DEBUG] METEOR Calculated: 30.59%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [12621, 3048, 365, 95]}
# ratio: 0.9999999999999775
# --- Epoch 06 Complete (Time: 4m 14s) ---
# Training Loss: 4.8249 | Dev Loss: 5.3724
# ⭐️ Dev METEOR: 30.59%
# ⭐️ Dev BLEU-4: 2.61%
#  >>> SAVED: New best model found (BLEU-4: 2.61%)
#
#
# Epoch 7 Training: 100%|██████████| 313/313 [02:39<00:00,  1.96it/s, loss=4.6216]
# Evaluating Epoch 7...
#    >>> [DEBUG] METEOR Calculated: 31.52%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13155, 3191, 426, 108]}
# ratio: 0.9999999999999775
# --- Epoch 07 Complete (Time: 4m 10s) ---
# Training Loss: 4.6422 | Dev Loss: 5.3153
# ⭐️ Dev METEOR: 31.52%
# ⭐️ Dev BLEU-4: 2.86%
#  >>> SAVED: New best model found (BLEU-4: 2.86%)
#
#
# Epoch 8 Training: 100%|██████████| 313/313 [02:40<00:00,  1.95it/s, loss=4.2417]
# Evaluating Epoch 8...
#    >>> [DEBUG] METEOR Calculated: 31.21%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13298, 3385, 480, 122]}
# ratio: 0.9999999999999775
# --- Epoch 08 Complete (Time: 4m 11s) ---
# Training Loss: 4.4948 | Dev Loss: 5.2811
# ⭐️ Dev METEOR: 31.21%
# ⭐️ Dev BLEU-4: 3.09%
#  >>> SAVED: New best model found (BLEU-4: 3.09%)
#
#
# Epoch 9 Training: 100%|██████████| 313/313 [02:42<00:00,  1.93it/s, loss=4.6580]
# Evaluating Epoch 9...
#    >>> [DEBUG] METEOR Calculated: 31.20%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13185, 3469, 527, 132]}
# ratio: 0.9999999999999775
# --- Epoch 09 Complete (Time: 4m 13s) ---
# Training Loss: 4.3666 | Dev Loss: 5.2587
# ⭐️ Dev METEOR: 31.20%
# ⭐️ Dev BLEU-4: 3.24%
#  >>> SAVED: New best model found (BLEU-4: 3.24%)
#
#
# Epoch 10 Training: 100%|█████████| 313/313 [02:42<00:00,  1.93it/s, loss=4.2801]
# Evaluating Epoch 10...
#    >>> [DEBUG] METEOR Calculated: 30.91%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13240, 3464, 555, 149]}
# ratio: 0.9999999999999775
# --- Epoch 10 Complete (Time: 4m 12s) ---
# Training Loss: 4.2501 | Dev Loss: 5.2468
# ⭐️ Dev METEOR: 30.91%
# ⭐️ Dev BLEU-4: 3.38%
#  >>> SAVED: New best model found (BLEU-4: 3.38%)
#
#
# Epoch 11 Training: 100%|█████████| 313/313 [02:40<00:00,  1.95it/s, loss=3.9561]
# Evaluating Epoch 11...
#    >>> [DEBUG] METEOR Calculated: 29.32%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13213, 3340, 574, 158]}
# ratio: 0.9999999999999775
# --- Epoch 11 Complete (Time: 4m 10s) ---
# Training Loss: 4.1392 | Dev Loss: 5.2597
# ⭐️ Dev METEOR: 29.32%
# ⭐️ Dev BLEU-4: 3.43%
#  >>> SAVED: New best model found (BLEU-4: 3.43%)
#
#
# Epoch 12 Training: 100%|█████████| 313/313 [02:41<00:00,  1.94it/s, loss=4.1493]
# Evaluating Epoch 12...
#    >>> [DEBUG] METEOR Calculated: 30.49%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13304, 3496, 600, 166]}
# ratio: 0.9999999999999775
# --- Epoch 12 Complete (Time: 4m 13s) ---
# Training Loss: 4.0370 | Dev Loss: 5.2754
# ⭐️ Dev METEOR: 30.49%
# ⭐️ Dev BLEU-4: 3.56%
#  >>> SAVED: New best model found (BLEU-4: 3.56%)
#
#
# Epoch 13 Training: 100%|█████████| 313/313 [02:42<00:00,  1.93it/s, loss=4.1330]
# Evaluating Epoch 13...
#    >>> [DEBUG] METEOR Calculated: 28.51%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13062, 3376, 659, 194]}
# ratio: 0.9999999999999775
# --- Epoch 13 Complete (Time: 4m 12s) ---
# Training Loss: 3.9419 | Dev Loss: 5.2902
# ⭐️ Dev METEOR: 28.51%
# ⭐️ Dev BLEU-4: 3.74%
#  >>> SAVED: New best model found (BLEU-4: 3.74%)
#
#
# Epoch 14 Training: 100%|█████████| 313/313 [02:44<00:00,  1.90it/s, loss=3.9339]
# Evaluating Epoch 14...
#    >>> [DEBUG] METEOR Calculated: 28.40%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13039, 3386, 690, 211]}
# ratio: 0.9999999999999775
# --- Epoch 14 Complete (Time: 4m 15s) ---
# Training Loss: 3.8450 | Dev Loss: 5.3003
# ⭐️ Dev METEOR: 28.40%
# ⭐️ Dev BLEU-4: 3.86%
#  >>> SAVED: New best model found (BLEU-4: 3.86%)
#
#
# Epoch 15 Training: 100%|█████████| 313/313 [02:40<00:00,  1.95it/s, loss=3.8688]
# Evaluating Epoch 15...
#    >>> [DEBUG] METEOR Calculated: 28.56%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13009, 3404, 689, 212]}
# ratio: 0.9999999999999775
# --- Epoch 15 Complete (Time: 4m 10s) ---
# Training Loss: 3.7534 | Dev Loss: 5.3203
# ⭐️ Dev METEOR: 28.56%
# ⭐️ Dev BLEU-4: 3.87%
#  >>> SAVED: New best model found (BLEU-4: 3.87%)
#
#
# Epoch 16 Training: 100%|█████████| 313/313 [02:43<00:00,  1.91it/s, loss=3.7861]
# Evaluating Epoch 16...
#    >>> [DEBUG] METEOR Calculated: 26.16%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [12834, 3214, 705, 219]}
# ratio: 0.9999999999999775
# --- Epoch 16 Complete (Time: 4m 14s) ---
# Training Loss: 3.6637 | Dev Loss: 5.3756
# ⭐️ Dev METEOR: 26.16%
# ⭐️ Dev BLEU-4: 3.85%
#  >>> No improvement in BLEU-4. Patience: 1/5
#
#
# Epoch 17 Training: 100%|█████████| 313/313 [02:43<00:00,  1.91it/s, loss=3.3477]
# Evaluating Epoch 17...
#    >>> [DEBUG] METEOR Calculated: 27.87%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [12927, 3403, 735, 233]}
# ratio: 0.9999999999999775
# --- Epoch 17 Complete (Time: 4m 14s) ---
# Training Loss: 3.5787 | Dev Loss: 5.3886
# ⭐️ Dev METEOR: 27.87%
# ⭐️ Dev BLEU-4: 4.02%
#  >>> SAVED: New best model found (BLEU-4: 4.02%)
#
#
# Epoch 18 Training: 100%|█████████| 313/313 [02:42<00:00,  1.92it/s, loss=3.2806]
# Evaluating Epoch 18...
#    >>> [DEBUG] METEOR Calculated: 28.05%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13124, 3476, 794, 260]}
# ratio: 0.9999999999999775
# --- Epoch 18 Complete (Time: 4m 12s) ---
# Training Loss: 3.4953 | Dev Loss: 5.4254
# ⭐️ Dev METEOR: 28.05%
# ⭐️ Dev BLEU-4: 4.25%
#  >>> SAVED: New best model found (BLEU-4: 4.25%)
#
#
# Epoch 19 Training: 100%|█████████| 313/313 [02:42<00:00,  1.93it/s, loss=3.4899]
# Evaluating Epoch 19...
#    >>> [DEBUG] METEOR Calculated: 29.43%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13474, 3577, 780, 261]}
# ratio: 0.9999999999999775
# --- Epoch 19 Complete (Time: 4m 13s) ---
# Training Loss: 3.4221 | Dev Loss: 5.4447
# ⭐️ Dev METEOR: 29.43%
# ⭐️ Dev BLEU-4: 4.29%
#  >>> SAVED: New best model found (BLEU-4: 4.29%)
#
#
# Epoch 20 Training: 100%|█████████| 313/313 [02:41<00:00,  1.93it/s, loss=3.4095]
# Evaluating Epoch 20...
#    >>> [DEBUG] METEOR Calculated: 29.47%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13455, 3580, 760, 239]}
# ratio: 0.9999999999999775
# --- Epoch 20 Complete (Time: 4m 12s) ---
# Training Loss: 3.3481 | Dev Loss: 5.4802
# ⭐️ Dev METEOR: 29.47%
# ⭐️ Dev BLEU-4: 4.17%
#  >>> No improvement in BLEU-4. Patience: 1/5
#
#
# Epoch 21 Training: 100%|█████████| 313/313 [02:42<00:00,  1.93it/s, loss=3.1627]
# Evaluating Epoch 21...
#    >>> [DEBUG] METEOR Calculated: 27.99%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13065, 3441, 786, 260]}
# ratio: 0.9999999999999775
# --- Epoch 21 Complete (Time: 4m 13s) ---
# Training Loss: 3.2744 | Dev Loss: 5.5270
# ⭐️ Dev METEOR: 27.99%
# ⭐️ Dev BLEU-4: 4.22%
#  >>> No improvement in BLEU-4. Patience: 2/5
#
#
# Epoch 22 Training: 100%|█████████| 313/313 [02:43<00:00,  1.92it/s, loss=3.3580]
# Evaluating Epoch 22...
#    >>> [DEBUG] METEOR Calculated: 28.58%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13246, 3487, 751, 231]}
# ratio: 0.9999999999999775
# --- Epoch 22 Complete (Time: 4m 13s) ---
# Training Loss: 3.2120 | Dev Loss: 5.5706
# ⭐️ Dev METEOR: 28.58%
# ⭐️ Dev BLEU-4: 4.08%
#  >>> No improvement in BLEU-4. Patience: 3/5
#
#
# Epoch 23 Training: 100%|█████████| 313/313 [02:42<00:00,  1.92it/s, loss=3.3337]
# Evaluating Epoch 23...
#    >>> [DEBUG] METEOR Calculated: 28.48%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13111, 3442, 745, 240]}
# ratio: 0.9999999999999775
# --- Epoch 23 Complete (Time: 4m 13s) ---
# Training Loss: 3.1492 | Dev Loss: 5.6135
# ⭐️ Dev METEOR: 28.48%
# ⭐️ Dev BLEU-4: 4.09%
#  >>> No improvement in BLEU-4. Patience: 4/5
#
#
# Epoch 24 Training: 100%|█████████| 313/313 [02:42<00:00,  1.93it/s, loss=3.1736]
# Evaluating Epoch 24...
#    >>> [DEBUG] METEOR Calculated: 29.23%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13306, 3502, 769, 249]}
# ratio: 0.9999999999999775
# --- Epoch 24 Complete (Time: 4m 13s) ---
# Training Loss: 3.0898 | Dev Loss: 5.6506
# ⭐️ Dev METEOR: 29.23%
# ⭐️ Dev BLEU-4: 4.19%
#  >>> No improvement in BLEU-4. Patience: 5/5
#
# *** EARLY STOPPING TRIGGERED (No improve in BLEU-4 for 5 epochs) ***
#
# Evaluating on test set using the BEST saved model ...
# Đã tải mô hình tốt nhất từ checkpoints/best_model.pt
#    >>> [DEBUG] METEOR Calculated: 28.46%
# {'testlen': 49513, 'reflen': 49513, 'guess': [49513, 47513, 45513, 43513], 'correct': [15092, 4080, 879, 279]}
# ratio: 0.9999999999999799
#
# --- FINAL TEST RESULTS ---
# Test Loss: 5.3598
# METEOR: 28.46%
# BLEU-1: 30.48%
# BLEU-2: 16.18%
# BLEU-3: 7.97%
# BLEU-4: 4.24%
# ROUGE-L: 29.04%

# %%
# !python LSTM_main.py
# Out:
# 2025-12-07 13:32:33.981773: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765114354.005155    2175 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765114354.012220    2175 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# [nltk_data] Downloading package wordnet to /usr/share/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /usr/share/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# Loading vocab ...
# Creating model ...
# Loading METEOR metric...
# [nltk_data] Downloading package wordnet to /usr/share/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /usr/share/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /usr/share/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# Loading dataset ...
# Starting training ...
# Epoch 1 Training: 100%|██████████| 157/157 [01:33<00:00,  1.68it/s, loss=5.5851]
# Evaluating Epoch 1...
#    >>> [DEBUG] METEOR Calculated: 12.29%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [5773, 405, 4, 0]}
# ratio: 0.9999999999999775
# --- Epoch 01 Complete (Time: 2m 36s) ---
# Training Loss: 6.1134 | Dev Loss: 6.4395
# ⭐️ Dev METEOR: 12.29%
# ⭐️ Dev BLEU-1: 13.03%
#  >>> SAVED: New best model found (BLEU-1: 13.03%)
#
#
# Epoch 2 Training: 100%|██████████| 157/157 [01:33<00:00,  1.68it/s, loss=5.6040]
# Evaluating Epoch 2...
#    >>> [DEBUG] METEOR Calculated: 17.38%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [7558, 875, 10, 0]}
# ratio: 0.9999999999999775
# --- Epoch 02 Complete (Time: 2m 32s) ---
# Training Loss: 5.7909 | Dev Loss: 6.2047
# ⭐️ Dev METEOR: 17.38%
# ⭐️ Dev BLEU-1: 17.06%
#  >>> SAVED: New best model found (BLEU-1: 17.06%)
#
#
# Epoch 3 Training: 100%|██████████| 157/157 [01:33<00:00,  1.68it/s, loss=5.6102]
# Evaluating Epoch 3...
#    >>> [DEBUG] METEOR Calculated: 21.04%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [8543, 1248, 33, 0]}
# ratio: 0.9999999999999775
# --- Epoch 03 Complete (Time: 2m 33s) ---
# Training Loss: 5.6736 | Dev Loss: 6.0676
# ⭐️ Dev METEOR: 21.04%
# ⭐️ Dev BLEU-1: 19.28%
#  >>> SAVED: New best model found (BLEU-1: 19.28%)
#
#
# Epoch 4 Training: 100%|██████████| 157/157 [01:33<00:00,  1.68it/s, loss=5.4881]
# Evaluating Epoch 4...
#    >>> [DEBUG] METEOR Calculated: 22.90%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [9116, 1617, 89, 18]}
# ratio: 0.9999999999999775
# --- Epoch 04 Complete (Time: 2m 34s) ---
# Training Loss: 5.5662 | Dev Loss: 5.9699
# ⭐️ Dev METEOR: 22.90%
# ⭐️ Dev BLEU-1: 20.57%
#  >>> SAVED: New best model found (BLEU-1: 20.57%)
#
#
# Epoch 5 Training: 100%|██████████| 157/157 [01:33<00:00,  1.68it/s, loss=5.3203]
# Evaluating Epoch 5...
#    >>> [DEBUG] METEOR Calculated: 21.83%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [9298, 1664, 122, 21]}
# ratio: 0.9999999999999775
# --- Epoch 05 Complete (Time: 2m 34s) ---
# Training Loss: 5.4712 | Dev Loss: 5.9738
# ⭐️ Dev METEOR: 21.83%
# ⭐️ Dev BLEU-1: 20.98%
#  >>> SAVED: New best model found (BLEU-1: 20.98%)
#
#
# Epoch 6 Training: 100%|██████████| 157/157 [01:32<00:00,  1.69it/s, loss=5.4796]
# Evaluating Epoch 6...
#    >>> [DEBUG] METEOR Calculated: 21.91%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [9558, 1769, 165, 20]}
# ratio: 0.9999999999999775
# --- Epoch 06 Complete (Time: 2m 34s) ---
# Training Loss: 5.3883 | Dev Loss: 5.9462
# ⭐️ Dev METEOR: 21.91%
# ⭐️ Dev BLEU-1: 21.57%
#  >>> SAVED: New best model found (BLEU-1: 21.57%)
#
#
# Epoch 7 Training: 100%|██████████| 157/157 [01:34<00:00,  1.66it/s, loss=4.9173]
# Evaluating Epoch 7...
#    >>> [DEBUG] METEOR Calculated: 21.98%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [8386, 2120, 297, 63]}
# ratio: 0.9999999999999775
# --- Epoch 07 Complete (Time: 2m 35s) ---
# Training Loss: 5.1101 | Dev Loss: 5.5044
# ⭐️ Dev METEOR: 21.98%
# ⭐️ Dev BLEU-1: 18.93%
#  >>> No improvement. Patience: 1/5
#
#
# Epoch 8 Training: 100%|██████████| 157/157 [01:33<00:00,  1.68it/s, loss=4.6110]
# Evaluating Epoch 8...
#    >>> [DEBUG] METEOR Calculated: 28.13%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [12414, 3089, 454, 110]}
# ratio: 0.9999999999999775
# --- Epoch 08 Complete (Time: 2m 33s) ---
# Training Loss: 4.7352 | Dev Loss: 5.3464
# ⭐️ Dev METEOR: 28.13%
# ⭐️ Dev BLEU-1: 28.02%
#  >>> SAVED: New best model found (BLEU-1: 28.02%)
#
#
# Epoch 9 Training: 100%|██████████| 157/157 [01:33<00:00,  1.68it/s, loss=4.6150]
# Evaluating Epoch 9...
#    >>> [DEBUG] METEOR Calculated: 28.21%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [12715, 3169, 512, 138]}
# ratio: 0.9999999999999775
# --- Epoch 09 Complete (Time: 2m 33s) ---
# Training Loss: 4.4999 | Dev Loss: 5.2620
# ⭐️ Dev METEOR: 28.21%
# ⭐️ Dev BLEU-1: 28.69%
#  >>> SAVED: New best model found (BLEU-1: 28.69%)
#
#
# Epoch 10 Training: 100%|█████████| 157/157 [01:33<00:00,  1.68it/s, loss=4.3000]
# Evaluating Epoch 10...
#    >>> [DEBUG] METEOR Calculated: 27.71%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13045, 3262, 592, 170]}
# ratio: 0.9999999999999775
# --- Epoch 10 Complete (Time: 2m 33s) ---
# Training Loss: 4.3287 | Dev Loss: 5.2278
# ⭐️ Dev METEOR: 27.71%
# ⭐️ Dev BLEU-1: 29.44%
#  >>> SAVED: New best model found (BLEU-1: 29.44%)
#
#
# Epoch 11 Training: 100%|█████████| 157/157 [01:33<00:00,  1.68it/s, loss=4.0728]
# Evaluating Epoch 11...
#    >>> [DEBUG] METEOR Calculated: 27.62%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13240, 3298, 672, 196]}
# ratio: 0.9999999999999775
# --- Epoch 11 Complete (Time: 2m 34s) ---
# Training Loss: 4.1812 | Dev Loss: 5.1847
# ⭐️ Dev METEOR: 27.62%
# ⭐️ Dev BLEU-1: 29.88%
#  >>> SAVED: New best model found (BLEU-1: 29.88%)
#
#
# Epoch 12 Training: 100%|█████████| 157/157 [01:33<00:00,  1.68it/s, loss=4.0326]
# Evaluating Epoch 12...
#    >>> [DEBUG] METEOR Calculated: 28.44%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13402, 3423, 682, 208]}
# ratio: 0.9999999999999775
# --- Epoch 12 Complete (Time: 2m 34s) ---
# Training Loss: 4.0553 | Dev Loss: 5.1798
# ⭐️ Dev METEOR: 28.44%
# ⭐️ Dev BLEU-1: 30.25%
#  >>> SAVED: New best model found (BLEU-1: 30.25%)
#
#
# Epoch 13 Training: 100%|█████████| 157/157 [01:31<00:00,  1.71it/s, loss=3.9398]
# Evaluating Epoch 13...
#    >>> [DEBUG] METEOR Calculated: 28.23%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13431, 3427, 687, 201]}
# ratio: 0.9999999999999775
# --- Epoch 13 Complete (Time: 2m 33s) ---
# Training Loss: 3.9376 | Dev Loss: 5.1696
# ⭐️ Dev METEOR: 28.23%
# ⭐️ Dev BLEU-1: 30.31%
#  >>> SAVED: New best model found (BLEU-1: 30.31%)
#
#
# Epoch 14 Training: 100%|█████████| 157/157 [01:34<00:00,  1.67it/s, loss=4.2059]
# Evaluating Epoch 14...
#    >>> [DEBUG] METEOR Calculated: 29.82%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13780, 3692, 778, 239]}
# ratio: 0.9999999999999775
# --- Epoch 14 Complete (Time: 2m 35s) ---
# Training Loss: 3.8307 | Dev Loss: 5.1550
# ⭐️ Dev METEOR: 29.82%
# ⭐️ Dev BLEU-1: 31.10%
#  >>> SAVED: New best model found (BLEU-1: 31.10%)
#
#
# Epoch 15 Training: 100%|█████████| 157/157 [01:33<00:00,  1.68it/s, loss=3.6654]
# Evaluating Epoch 15...
#    >>> [DEBUG] METEOR Calculated: 28.98%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13602, 3607, 766, 242]}
# ratio: 0.9999999999999775
# --- Epoch 15 Complete (Time: 2m 34s) ---
# Training Loss: 3.7253 | Dev Loss: 5.1764
# ⭐️ Dev METEOR: 28.98%
# ⭐️ Dev BLEU-1: 30.70%
#  >>> No improvement. Patience: 1/5
#
#
# Epoch 16 Training: 100%|█████████| 157/157 [01:34<00:00,  1.66it/s, loss=3.7450]
# Evaluating Epoch 16...
#    >>> [DEBUG] METEOR Calculated: 29.56%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13519, 3713, 841, 266]}
# ratio: 0.9999999999999775
# --- Epoch 16 Complete (Time: 2m 35s) ---
# Training Loss: 3.6307 | Dev Loss: 5.1840
# ⭐️ Dev METEOR: 29.56%
# ⭐️ Dev BLEU-1: 30.51%
#  >>> No improvement. Patience: 2/5
#
#
# Epoch 17 Training: 100%|█████████| 157/157 [01:33<00:00,  1.67it/s, loss=3.4659]
# Evaluating Epoch 17...
#    >>> [DEBUG] METEOR Calculated: 28.09%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13520, 3590, 827, 258]}
# ratio: 0.9999999999999775
# --- Epoch 17 Complete (Time: 2m 34s) ---
# Training Loss: 3.5374 | Dev Loss: 5.2294
# ⭐️ Dev METEOR: 28.09%
# ⭐️ Dev BLEU-1: 30.51%
#  >>> No improvement. Patience: 3/5
#
#
# Epoch 18 Training: 100%|█████████| 157/157 [01:32<00:00,  1.69it/s, loss=3.6108]
# Evaluating Epoch 18...
#    >>> [DEBUG] METEOR Calculated: 28.82%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13478, 3663, 829, 265]}
# ratio: 0.9999999999999775
# --- Epoch 18 Complete (Time: 2m 34s) ---
# Training Loss: 3.4480 | Dev Loss: 5.2442
# ⭐️ Dev METEOR: 28.82%
# ⭐️ Dev BLEU-1: 30.42%
#  >>> No improvement. Patience: 4/5
#
#
# Epoch 19 Training: 100%|█████████| 157/157 [01:33<00:00,  1.68it/s, loss=3.1535]
# Evaluating Epoch 19...
#    >>> [DEBUG] METEOR Calculated: 29.31%
# {'testlen': 44311, 'reflen': 44311, 'guess': [44311, 42311, 40311, 38311], 'correct': [13735, 3780, 917, 291]}
# ratio: 0.9999999999999775
# --- Epoch 19 Complete (Time: 2m 34s) ---
# Training Loss: 3.3603 | Dev Loss: 5.2671
# ⭐️ Dev METEOR: 29.31%
# ⭐️ Dev BLEU-1: 31.00%
#  >>> No improvement. Patience: 5/5
#
# *** EARLY STOPPING TRIGGERED ***
#
# Evaluating on test set using the BEST saved model ...
# Đã tải mô hình tốt nhất từ checkpoints/best_model.pt
#    >>> [DEBUG] METEOR Calculated: 28.80%
# {'testlen': 49513, 'reflen': 49513, 'guess': [49513, 47513, 45513, 43513], 'correct': [15428, 4150, 927, 286]}
# ratio: 0.9999999999999799
#
# --- FINAL TEST RESULTS ---
# Test Loss: 5.0696
# METEOR: 28.80%
# BLEU-1: 31.16%
# BLEU-2: 16.50%
# BLEU-3: 8.21%
# BLEU-4: 4.37%
# ROUGE-L: 29.42%
